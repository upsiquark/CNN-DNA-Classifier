# %%
import pylab as pl
import numpy as np
import scipy as sp
import scipy.optimize as spo
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LogisticRegression
import tensorflow as tf
from tensorflow import keras
import pydot
import graphviz

# %%
# Prepare the Training and Validation Data

batch_x_train = []
batch_y_train = []

df_1 = pd.read_csv('np_lin_400.csv') 

for index, rows in df_1.iterrows():
    batch_y_train.append(0)
    list_1 = rows
    batch_x_train.append(list_1)
    
df_2 = pd.read_csv('np_circ_400.csv')            

for index, rows in df_2.iterrows():
    batch_y_train.append(1)
    list_2 = rows
    batch_x_train.append(list_2)

batch_x_train = np.asarray(batch_x_train)
batch_y_train = tf.keras.utils.to_categorical(batch_y_train, num_classes=2)
batch_y_test = batch_y_train

batch_x_test = []

df_3 = pd.read_csv('np_t_lin_400.csv')

for index, rows in df_3.iterrows():
    list_3 = rows
    batch_x_test.append(list_3)
    
df_4 = pd.read_csv('np_t_circ_400.csv')
for index, rows in df_4.iterrows():
    list_4 = rows
    batch_x_test.append(list_4)
    
batch_x_test = np.asarray(batch_x_test)

#data standardization
batch_x_train = batch_x_train.reshape((batch_x_train.shape[0], batch_x_train.shape[1], 1)) 
batch_x_test = batch_x_test.reshape((batch_x_test.shape[0], batch_x_test.shape[1], 1))

num_classes = len(np.unique(batch_y_train))
idx = np.random.permutation(len(batch_x_train))
batch_x_train = batch_x_train[idx]
batch_y_train = batch_y_train[idx]

tf.keras.backend.clear_session()

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=2, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=2, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=2, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=batch_x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 200
batch_size = 20

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=25, min_lr=0.001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_accuracy"],
)
history = model.fit(
    batch_x_train,
    batch_y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.5427 - loss: 0.6888 - val_categorical_accuracy: 0.5600 - val_loss: 0.6746 - learning_rate: 0.0010
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6156 - loss: 0.6365 - val_categorical_accuracy: 0.5600 - val_loss: 0.6793 - learning_rate: 0.0010
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6633 - loss: 0.6181 - val_categorical_accuracy: 0.4800 - val_loss: 0.7026 - learning_rate: 0.0010
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6332 - loss: 0.6217 - val_categorical_accuracy: 0.6200 - val_loss: 0.6685 - learning_rate: 0.0010
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6683 - loss: 0.6095 - val_categorical_accuracy: 0.5400 - val_loss: 0.6918 - learning_rate: 0.0010
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6608 - loss: 0.6048 - val_categorical_accuracy: 0.6500 - val_loss: 0.6344 - learning_rate: 0.0010
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6457 - loss: 0.6126 - val_categorical_accuracy: 0.4800 - val_loss: 0.8144 - learning_rate: 0.0010
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6533 - loss: 0.5967 - val_categorical_accuracy: 0.4600 - val_loss: 0.7459 - learning_rate: 0.0010
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6382 - loss: 0.6138 - val_categorical_accuracy: 0.6700 - val_loss: 0.6152 - learning_rate: 0.0010
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6734 - loss: 0.5879 - val_categorical_accuracy: 0.5200 - val_loss: 0.7626 - learning_rate: 0.0010
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6734 - loss: 0.5989 - val_categorical_accuracy: 0.6500 - val_loss: 0.6127 - learning_rate: 0.0010
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6759 - loss: 0.5890 - val_categorical_accuracy: 0.6500 - val_loss: 0.6597 - learning_rate: 0.0010
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6608 - loss: 0.6049 - val_categorical_accuracy: 0.6500 - val_loss: 0.6619 - learning_rate: 0.0010
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6784 - loss: 0.5956 - val_categorical_accuracy: 0.6600 - val_loss: 0.6136 - learning_rate: 0.0010
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6809 - loss: 0.5908 - val_categorical_accuracy: 0.6500 - val_loss: 0.6547 - learning_rate: 0.0010
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6809 - loss: 0.5996 - val_categorical_accuracy: 0.6700 - val_loss: 0.5968 - learning_rate: 0.0010
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6658 - loss: 0.5821 - val_categorical_accuracy: 0.6700 - val_loss: 0.5967 - learning_rate: 0.0010
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6834 - loss: 0.5802 - val_categorical_accuracy: 0.6400 - val_loss: 0.6030 - learning_rate: 0.0010
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6683 - loss: 0.5783 - val_categorical_accuracy: 0.6500 - val_loss: 0.6026 - learning_rate: 0.0010
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6759 - loss: 0.5822 - val_categorical_accuracy: 0.6200 - val_loss: 0.6102 - learning_rate: 0.0010
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6910 - loss: 0.5879 - val_categorical_accuracy: 0.6600 - val_loss: 0.5971 - learning_rate: 0.0010
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6734 - loss: 0.5853 - val_categorical_accuracy: 0.6500 - val_loss: 0.5942 - learning_rate: 0.0010
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6859 - loss: 0.5741 - val_categorical_accuracy: 0.6600 - val_loss: 0.5899 - learning_rate: 0.0010
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6784 - loss: 0.5837 - val_categorical_accuracy: 0.6000 - val_loss: 0.6424 - learning_rate: 0.0010
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6784 - loss: 0.5785 - val_categorical_accuracy: 0.6500 - val_loss: 0.6037 - learning_rate: 0.0010
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6734 - loss: 0.5834 - val_categorical_accuracy: 0.6200 - val_loss: 0.6190 - learning_rate: 0.0010
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6633 - loss: 0.5893 - val_categorical_accuracy: 0.6600 - val_loss: 0.6027 - learning_rate: 0.0010
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6633 - loss: 0.5876 - val_categorical_accuracy: 0.5900 - val_loss: 0.6407 - learning_rate: 0.0010
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6884 - loss: 0.5877 - val_categorical_accuracy: 0.6300 - val_loss: 0.5976 - learning_rate: 0.0010
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6910 - loss: 0.5754 - val_categorical_accuracy: 0.6700 - val_loss: 0.5881 - learning_rate: 0.0010
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7085 - loss: 0.5629 - val_categorical_accuracy: 0.6900 - val_loss: 0.5927 - learning_rate: 0.0010
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6533 - loss: 0.5983 - val_categorical_accuracy: 0.6200 - val_loss: 0.6251 - learning_rate: 0.0010
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6658 - loss: 0.5914 - val_categorical_accuracy: 0.6600 - val_loss: 0.5945 - learning_rate: 0.0010
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6784 - loss: 0.5893 - val_categorical_accuracy: 0.6700 - val_loss: 0.5910 - learning_rate: 0.0010
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7085 - loss: 0.5703 - val_categorical_accuracy: 0.6600 - val_loss: 0.6113 - learning_rate: 0.0010
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6784 - loss: 0.5702 - val_categorical_accuracy: 0.6600 - val_loss: 0.5889 - learning_rate: 0.0010
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6633 - loss: 0.5691 - val_categorical_accuracy: 0.7300 - val_loss: 0.5955 - learning_rate: 0.0010
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6960 - loss: 0.5653 - val_categorical_accuracy: 0.6900 - val_loss: 0.6050 - learning_rate: 0.0010
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7060 - loss: 0.5604 - val_categorical_accuracy: 0.5400 - val_loss: 0.8951 - learning_rate: 0.0010
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6985 - loss: 0.5675 - val_categorical_accuracy: 0.6800 - val_loss: 0.5953 - learning_rate: 0.0010
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6583 - loss: 0.5864 - val_categorical_accuracy: 0.6600 - val_loss: 0.6028 - learning_rate: 0.0010
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6910 - loss: 0.5635 - val_categorical_accuracy: 0.6000 - val_loss: 0.6504 - learning_rate: 0.0010
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7010 - loss: 0.5628 - val_categorical_accuracy: 0.5900 - val_loss: 0.6588 - learning_rate: 0.0010
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6734 - loss: 0.5724 - val_categorical_accuracy: 0.5700 - val_loss: 0.6248 - learning_rate: 0.0010
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6960 - loss: 0.5557 - val_categorical_accuracy: 0.6600 - val_loss: 0.6064 - learning_rate: 0.0010
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6859 - loss: 0.5728 - val_categorical_accuracy: 0.5500 - val_loss: 0.7954 - learning_rate: 0.0010
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7035 - loss: 0.5665 - val_categorical_accuracy: 0.5900 - val_loss: 0.6356 - learning_rate: 0.0010
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7010 - loss: 0.5520 - val_categorical_accuracy: 0.5900 - val_loss: 0.6400 - learning_rate: 0.0010
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7085 - loss: 0.5624 - val_categorical_accuracy: 0.6800 - val_loss: 0.5987 - learning_rate: 0.0010
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6759 - loss: 0.5862 - val_categorical_accuracy: 0.5800 - val_loss: 0.6626 - learning_rate: 0.0010
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7085 - loss: 0.5673 - val_categorical_accuracy: 0.6700 - val_loss: 0.5957 - learning_rate: 0.0010
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6985 - loss: 0.5655 - val_categorical_accuracy: 0.5600 - val_loss: 0.6818 - learning_rate: 0.0010
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6884 - loss: 0.5574 - val_categorical_accuracy: 0.6700 - val_loss: 0.6126 - learning_rate: 0.0010
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6910 - loss: 0.5557 - val_categorical_accuracy: 0.5800 - val_loss: 0.6416 - learning_rate: 0.0010
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6960 - loss: 0.5561 - val_categorical_accuracy: 0.6800 - val_loss: 0.6047 - learning_rate: 0.0010
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6884 - loss: 0.5634 - val_categorical_accuracy: 0.6300 - val_loss: 0.6246 - learning_rate: 0.0010
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7136 - loss: 0.5523 - val_categorical_accuracy: 0.6000 - val_loss: 0.6459 - learning_rate: 0.0010
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6859 - loss: 0.5586 - val_categorical_accuracy: 0.6600 - val_loss: 0.6113 - learning_rate: 0.0010
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7111 - loss: 0.5543 - val_categorical_accuracy: 0.6600 - val_loss: 0.6122 - learning_rate: 0.0010
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7060 - loss: 0.5550 - val_categorical_accuracy: 0.6300 - val_loss: 0.6232 - learning_rate: 0.0010
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6834 - loss: 0.5505 - val_categorical_accuracy: 0.6200 - val_loss: 0.6435 - learning_rate: 0.0010
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7111 - loss: 0.5450 - val_categorical_accuracy: 0.5500 - val_loss: 0.7041 - learning_rate: 0.0010
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6884 - loss: 0.5656 - val_categorical_accuracy: 0.5800 - val_loss: 0.6504 - learning_rate: 0.0010
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7111 - loss: 0.5375 - val_categorical_accuracy: 0.6000 - val_loss: 0.6813 - learning_rate: 0.0010
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6884 - loss: 0.5576 - val_categorical_accuracy: 0.6100 - val_loss: 0.6542 - learning_rate: 0.0010
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6935 - loss: 0.5578 - val_categorical_accuracy: 0.5500 - val_loss: 0.6775 - learning_rate: 0.0010
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7211 - loss: 0.5486 - val_categorical_accuracy: 0.5400 - val_loss: 0.7164 - learning_rate: 0.0010
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6910 - loss: 0.5463 - val_categorical_accuracy: 0.6400 - val_loss: 0.6306 - learning_rate: 0.0010
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6834 - loss: 0.5577 - val_categorical_accuracy: 0.5800 - val_loss: 0.6803 - learning_rate: 0.0010
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7136 - loss: 0.5552 - val_categorical_accuracy: 0.5400 - val_loss: 0.7544 - learning_rate: 0.0010
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7161 - loss: 0.5359 - val_categorical_accuracy: 0.7000 - val_loss: 0.6037 - learning_rate: 0.0010
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7111 - loss: 0.5455 - val_categorical_accuracy: 0.6000 - val_loss: 0.6325 - learning_rate: 0.0010
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7085 - loss: 0.5437 - val_categorical_accuracy: 0.5900 - val_loss: 0.6496 - learning_rate: 0.0010
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7035 - loss: 0.5419 - val_categorical_accuracy: 0.5500 - val_loss: 1.0576 - learning_rate: 0.0010
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6809 - loss: 0.5712 - val_categorical_accuracy: 0.6600 - val_loss: 0.6636 - learning_rate: 0.0010
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6809 - loss: 0.5655 - val_categorical_accuracy: 0.6800 - val_loss: 0.6010 - learning_rate: 0.0010
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7236 - loss: 0.5507 - val_categorical_accuracy: 0.6900 - val_loss: 0.5994 - learning_rate: 0.0010
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7035 - loss: 0.5276 - val_categorical_accuracy: 0.6600 - val_loss: 0.6159 - learning_rate: 0.0010
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7261 - loss: 0.5333 - val_categorical_accuracy: 0.6100 - val_loss: 0.6942 - learning_rate: 0.0010
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6734 - loss: 0.5533 - val_categorical_accuracy: 0.6700 - val_loss: 0.6014 - learning_rate: 0.0010
# Epoch 80: early stopping

# %%
model = keras.models.load_model("best_model.keras")

test_loss, test_acc = model.evaluate(batch_x_test, batch_y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.7369 - loss: 0.5376
# Test accuracy 0.736947774887085
# Test loss 0.5375807285308838

# %%
metric = "categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
