# %%
import pylab as pl
import numpy as np
import scipy as sp
import scipy.optimize as spo
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LogisticRegression
import tensorflow as tf
from tensorflow import keras
import pydot
import graphviz

# %%
# Prepare the Training and Validation Data

batch_x_train = []
batch_y_train = []

df_1 = pd.read_csv('np_lin_100.csv') 

for index, rows in df_1.iterrows():
    batch_y_train.append(0)
    list_1 = rows
    batch_x_train.append(list_1)
    
df_2 = pd.read_csv('np_circ_100.csv')            

for index, rows in df_2.iterrows():
    batch_y_train.append(1)
    list_2 = rows
    batch_x_train.append(list_2)

batch_x_train = np.asarray(batch_x_train)
batch_y_train = tf.keras.utils.to_categorical(batch_y_train, num_classes=2)
batch_y_test = batch_y_train

batch_x_test = []

df_3 = pd.read_csv('np_lin_300.csv')

for index, rows in df_3.iterrows():
    list_3 = rows
    batch_x_test.append(list_3)
    
df_4 = pd.read_csv('np_circ_300.csv')
for index, rows in df_4.iterrows():
    list_4 = rows
    batch_x_test.append(list_4)
    
batch_x_test = np.asarray(batch_x_test)

#data standardization
batch_x_train = batch_x_train.reshape((batch_x_train.shape[0], batch_x_train.shape[1], 1)) 
batch_x_test = batch_x_test.reshape((batch_x_test.shape[0], batch_x_test.shape[1], 1))

num_classes = len(np.unique(batch_y_train))
idx = np.random.permutation(len(batch_x_train))
batch_x_train = batch_x_train[idx]
batch_y_train = batch_y_train[idx]

tf.keras.backend.clear_session()

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=2, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=2, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=2, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=batch_x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 200
batch_size = 20

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=25, min_lr=0.001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_accuracy"],
)
history = model.fit(
    batch_x_train,
    batch_y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.7538 - loss: 0.4668 - val_categorical_accuracy: 0.7300 - val_loss: 0.4895 - learning_rate: 0.0010
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7663 - loss: 0.4636 - val_categorical_accuracy: 0.7100 - val_loss: 0.5028 - learning_rate: 0.0010
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7663 - loss: 0.4604 - val_categorical_accuracy: 0.5700 - val_loss: 0.6284 - learning_rate: 0.0010
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7688 - loss: 0.4479 - val_categorical_accuracy: 0.7600 - val_loss: 0.4995 - learning_rate: 0.0010
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7714 - loss: 0.4368 - val_categorical_accuracy: 0.6100 - val_loss: 0.6209 - learning_rate: 0.0010
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7940 - loss: 0.4381 - val_categorical_accuracy: 0.7300 - val_loss: 0.4895 - learning_rate: 0.0010
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7789 - loss: 0.4508 - val_categorical_accuracy: 0.5100 - val_loss: 0.7514 - learning_rate: 0.0010
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7638 - loss: 0.4512 - val_categorical_accuracy: 0.7000 - val_loss: 0.5041 - learning_rate: 0.0010
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7688 - loss: 0.4505 - val_categorical_accuracy: 0.7600 - val_loss: 0.4952 - learning_rate: 0.0010
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4496 - val_categorical_accuracy: 0.7200 - val_loss: 0.4849 - learning_rate: 0.0010
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7538 - loss: 0.4543 - val_categorical_accuracy: 0.7500 - val_loss: 0.5283 - learning_rate: 0.0010
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4416 - val_categorical_accuracy: 0.7400 - val_loss: 0.5229 - learning_rate: 0.0010
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7688 - loss: 0.4354 - val_categorical_accuracy: 0.7600 - val_loss: 0.5872 - learning_rate: 0.0010
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7437 - loss: 0.4793 - val_categorical_accuracy: 0.6300 - val_loss: 0.5585 - learning_rate: 0.0010
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7688 - loss: 0.4461 - val_categorical_accuracy: 0.7000 - val_loss: 0.5007 - learning_rate: 0.0010
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4289 - val_categorical_accuracy: 0.7000 - val_loss: 0.5064 - learning_rate: 0.0010
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7513 - loss: 0.4492 - val_categorical_accuracy: 0.7600 - val_loss: 0.5354 - learning_rate: 0.0010
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7839 - loss: 0.4383 - val_categorical_accuracy: 0.7200 - val_loss: 0.4927 - learning_rate: 0.0010
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7638 - loss: 0.4365 - val_categorical_accuracy: 0.7500 - val_loss: 0.4968 - learning_rate: 0.0010
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7714 - loss: 0.4378 - val_categorical_accuracy: 0.6700 - val_loss: 0.5320 - learning_rate: 0.0010
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7764 - loss: 0.4370 - val_categorical_accuracy: 0.6200 - val_loss: 0.5906 - learning_rate: 0.0010
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4314 - val_categorical_accuracy: 0.7700 - val_loss: 0.6795 - learning_rate: 0.0010
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7462 - loss: 0.4748 - val_categorical_accuracy: 0.5400 - val_loss: 0.8930 - learning_rate: 0.0010
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7814 - loss: 0.4521 - val_categorical_accuracy: 0.7500 - val_loss: 0.5352 - learning_rate: 0.0010
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7688 - loss: 0.4605 - val_categorical_accuracy: 0.6200 - val_loss: 0.5402 - learning_rate: 0.0010
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7638 - loss: 0.4575 - val_categorical_accuracy: 0.6300 - val_loss: 0.5474 - learning_rate: 0.0010
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7714 - loss: 0.4378 - val_categorical_accuracy: 0.5500 - val_loss: 0.7052 - learning_rate: 0.0010
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7739 - loss: 0.4293 - val_categorical_accuracy: 0.6400 - val_loss: 0.6174 - learning_rate: 0.0010
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7990 - loss: 0.4228 - val_categorical_accuracy: 0.6800 - val_loss: 0.5496 - learning_rate: 0.0010
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7814 - loss: 0.4400 - val_categorical_accuracy: 0.6100 - val_loss: 0.6750 - learning_rate: 0.0010
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7286 - loss: 0.4629 - val_categorical_accuracy: 0.7400 - val_loss: 0.4952 - learning_rate: 0.0010
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7538 - loss: 0.4555 - val_categorical_accuracy: 0.6700 - val_loss: 0.5346 - learning_rate: 0.0010
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7613 - loss: 0.4483 - val_categorical_accuracy: 0.7300 - val_loss: 0.4975 - learning_rate: 0.0010
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4250 - val_categorical_accuracy: 0.7200 - val_loss: 0.5158 - learning_rate: 0.0010
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7739 - loss: 0.4305 - val_categorical_accuracy: 0.6300 - val_loss: 0.5841 - learning_rate: 0.0010
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7638 - loss: 0.4444 - val_categorical_accuracy: 0.6100 - val_loss: 0.5975 - learning_rate: 0.0010
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7915 - loss: 0.4383 - val_categorical_accuracy: 0.7700 - val_loss: 0.5156 - learning_rate: 0.0010
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4468 - val_categorical_accuracy: 0.7600 - val_loss: 0.5044 - learning_rate: 0.0010
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8166 - loss: 0.4323 - val_categorical_accuracy: 0.6500 - val_loss: 0.5489 - learning_rate: 0.0010
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4202 - val_categorical_accuracy: 0.6700 - val_loss: 0.5531 - learning_rate: 0.0010
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8040 - loss: 0.4354 - val_categorical_accuracy: 0.7700 - val_loss: 0.5584 - learning_rate: 0.0010
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4450 - val_categorical_accuracy: 0.7700 - val_loss: 0.6509 - learning_rate: 0.0010
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7714 - loss: 0.4481 - val_categorical_accuracy: 0.6600 - val_loss: 0.5750 - learning_rate: 0.0010
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8065 - loss: 0.4269 - val_categorical_accuracy: 0.7200 - val_loss: 0.4851 - learning_rate: 0.0010
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4380 - val_categorical_accuracy: 0.5800 - val_loss: 0.6741 - learning_rate: 0.0010
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7714 - loss: 0.4343 - val_categorical_accuracy: 0.4600 - val_loss: 1.1182 - learning_rate: 0.0010
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8065 - loss: 0.4213 - val_categorical_accuracy: 0.7400 - val_loss: 0.5175 - learning_rate: 0.0010
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8166 - loss: 0.4203 - val_categorical_accuracy: 0.7100 - val_loss: 0.5096 - learning_rate: 0.0010
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7688 - loss: 0.4346 - val_categorical_accuracy: 0.5900 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7839 - loss: 0.4292 - val_categorical_accuracy: 0.6000 - val_loss: 0.6018 - learning_rate: 0.0010
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8090 - loss: 0.4145 - val_categorical_accuracy: 0.7000 - val_loss: 0.5136 - learning_rate: 0.0010
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7412 - loss: 0.4559 - val_categorical_accuracy: 0.4900 - val_loss: 0.8164 - learning_rate: 0.0010
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7764 - loss: 0.4369 - val_categorical_accuracy: 0.6300 - val_loss: 0.5750 - learning_rate: 0.0010
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7940 - loss: 0.4249 - val_categorical_accuracy: 0.6500 - val_loss: 0.5553 - learning_rate: 0.0010
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4077 - val_categorical_accuracy: 0.6200 - val_loss: 0.5594 - learning_rate: 0.0010
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7990 - loss: 0.4189 - val_categorical_accuracy: 0.6300 - val_loss: 0.5884 - learning_rate: 0.0010
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8040 - loss: 0.4204 - val_categorical_accuracy: 0.7100 - val_loss: 0.5084 - learning_rate: 0.0010
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7663 - loss: 0.4361 - val_categorical_accuracy: 0.7500 - val_loss: 0.4791 - learning_rate: 0.0010
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7864 - loss: 0.4320 - val_categorical_accuracy: 0.6200 - val_loss: 0.6209 - learning_rate: 0.0010
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7940 - loss: 0.4302 - val_categorical_accuracy: 0.6500 - val_loss: 0.5920 - learning_rate: 0.0010
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4267 - val_categorical_accuracy: 0.7000 - val_loss: 0.5292 - learning_rate: 0.0010
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7688 - loss: 0.4250 - val_categorical_accuracy: 0.7000 - val_loss: 0.5129 - learning_rate: 0.0010
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7965 - loss: 0.4139 - val_categorical_accuracy: 0.7600 - val_loss: 0.5136 - learning_rate: 0.0010
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4203 - val_categorical_accuracy: 0.7400 - val_loss: 0.4979 - learning_rate: 0.0010
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7915 - loss: 0.4174 - val_categorical_accuracy: 0.6600 - val_loss: 0.5684 - learning_rate: 0.0010
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7839 - loss: 0.4279 - val_categorical_accuracy: 0.7400 - val_loss: 0.5102 - learning_rate: 0.0010
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8015 - loss: 0.4082 - val_categorical_accuracy: 0.6200 - val_loss: 0.6204 - learning_rate: 0.0010
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8015 - loss: 0.4078 - val_categorical_accuracy: 0.7400 - val_loss: 0.5419 - learning_rate: 0.0010
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8040 - loss: 0.3985 - val_categorical_accuracy: 0.6500 - val_loss: 0.5633 - learning_rate: 0.0010
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7864 - loss: 0.4235 - val_categorical_accuracy: 0.5800 - val_loss: 0.7380 - learning_rate: 0.0010
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7839 - loss: 0.4314 - val_categorical_accuracy: 0.6500 - val_loss: 0.5783 - learning_rate: 0.0010
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8116 - loss: 0.4164 - val_categorical_accuracy: 0.5800 - val_loss: 0.6540 - learning_rate: 0.0010
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7864 - loss: 0.4153 - val_categorical_accuracy: 0.5600 - val_loss: 0.7338 - learning_rate: 0.0010
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4380 - val_categorical_accuracy: 0.5900 - val_loss: 0.6408 - learning_rate: 0.0010
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7739 - loss: 0.4370 - val_categorical_accuracy: 0.5600 - val_loss: 0.6815 - learning_rate: 0.0010
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7714 - loss: 0.4358 - val_categorical_accuracy: 0.5800 - val_loss: 0.6454 - learning_rate: 0.0010
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4089 - val_categorical_accuracy: 0.6300 - val_loss: 0.5771 - learning_rate: 0.0010
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7990 - loss: 0.4149 - val_categorical_accuracy: 0.6500 - val_loss: 0.6015 - learning_rate: 0.0010
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7915 - loss: 0.4276 - val_categorical_accuracy: 0.7500 - val_loss: 0.5782 - learning_rate: 0.0010
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7839 - loss: 0.4172 - val_categorical_accuracy: 0.5100 - val_loss: 0.8274 - learning_rate: 0.0010
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4212 - val_categorical_accuracy: 0.5700 - val_loss: 0.6637 - learning_rate: 0.0010
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7940 - loss: 0.4270 - val_categorical_accuracy: 0.6100 - val_loss: 0.6328 - learning_rate: 0.0010
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4442 - val_categorical_accuracy: 0.5200 - val_loss: 0.9007 - learning_rate: 0.0010
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8116 - loss: 0.4082 - val_categorical_accuracy: 0.7200 - val_loss: 0.5136 - learning_rate: 0.0010
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8015 - loss: 0.4031 - val_categorical_accuracy: 0.6400 - val_loss: 0.6050 - learning_rate: 0.0010
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8015 - loss: 0.4079 - val_categorical_accuracy: 0.6000 - val_loss: 0.6643 - learning_rate: 0.0010
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8015 - loss: 0.3994 - val_categorical_accuracy: 0.7100 - val_loss: 0.5518 - learning_rate: 0.0010
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8040 - loss: 0.4055 - val_categorical_accuracy: 0.5900 - val_loss: 0.7460 - learning_rate: 0.0010
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7915 - loss: 0.4214 - val_categorical_accuracy: 0.5900 - val_loss: 0.6369 - learning_rate: 0.0010
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7513 - loss: 0.4363 - val_categorical_accuracy: 0.6100 - val_loss: 0.6469 - learning_rate: 0.0010
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8040 - loss: 0.4126 - val_categorical_accuracy: 0.7300 - val_loss: 0.5140 - learning_rate: 0.0010
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4000 - val_categorical_accuracy: 0.6100 - val_loss: 0.6436 - learning_rate: 0.0010
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7990 - loss: 0.4059 - val_categorical_accuracy: 0.6800 - val_loss: 0.5356 - learning_rate: 0.0010
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4169 - val_categorical_accuracy: 0.6100 - val_loss: 0.6310 - learning_rate: 0.0010
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7839 - loss: 0.4134 - val_categorical_accuracy: 0.5900 - val_loss: 0.7331 - learning_rate: 0.0010
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7688 - loss: 0.4515 - val_categorical_accuracy: 0.5900 - val_loss: 0.6574 - learning_rate: 0.0010
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7814 - loss: 0.4139 - val_categorical_accuracy: 0.6900 - val_loss: 0.5470 - learning_rate: 0.0010
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4098 - val_categorical_accuracy: 0.7600 - val_loss: 0.5273 - learning_rate: 0.0010
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7915 - loss: 0.4132 - val_categorical_accuracy: 0.7300 - val_loss: 0.5095 - learning_rate: 0.0010
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8090 - loss: 0.3986 - val_categorical_accuracy: 0.7700 - val_loss: 0.5313 - learning_rate: 0.0010
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8015 - loss: 0.3949 - val_categorical_accuracy: 0.7400 - val_loss: 0.5038 - learning_rate: 0.0010
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7864 - loss: 0.4165 - val_categorical_accuracy: 0.7000 - val_loss: 0.5715 - learning_rate: 0.0010
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8191 - loss: 0.4041 - val_categorical_accuracy: 0.7500 - val_loss: 0.5071 - learning_rate: 0.0010
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8116 - loss: 0.3851 - val_categorical_accuracy: 0.7600 - val_loss: 0.6064 - learning_rate: 0.0010
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7990 - loss: 0.4038 - val_categorical_accuracy: 0.6800 - val_loss: 0.5697 - learning_rate: 0.0010
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8015 - loss: 0.3949 - val_categorical_accuracy: 0.7700 - val_loss: 0.5328 - learning_rate: 0.0010
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7764 - loss: 0.4285 - val_categorical_accuracy: 0.6500 - val_loss: 0.5779 - learning_rate: 0.0010
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7739 - loss: 0.4333 - val_categorical_accuracy: 0.7600 - val_loss: 0.5997 - learning_rate: 0.0010
# Epoch 108: early stopping

# %%
model = keras.models.load_model("best_model.keras")

test_loss, test_acc = model.evaluate(batch_x_test, batch_y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.4759 - loss: 0.8134
# Test accuracy 0.47590360045433044
# Test loss 0.8133550882339478

# %%
metric = "categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
