# %%
import pylab as pl
import numpy as np
import scipy as sp
import scipy.optimize as spo
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LogisticRegression
import tensorflow as tf
from tensorflow import keras
import pydot
import graphviz

# %%
# Prepare the Training and Validation Data

batch_x_train = []
batch_y_train = []

df_1 = pd.read_csv('np_lin_300.csv') 

for index, rows in df_1.iterrows():
    batch_y_train.append(0)
    list_1 = rows
    batch_x_train.append(list_1)
    
df_2 = pd.read_csv('np_circ_300.csv')            

for index, rows in df_2.iterrows():
    batch_y_train.append(1)
    list_2 = rows
    batch_x_train.append(list_2)

batch_x_train = np.asarray(batch_x_train)
batch_y_train = tf.keras.utils.to_categorical(batch_y_train, num_classes=2)
batch_y_test = batch_y_train

batch_x_test = []

df_3 = pd.read_csv('np_t_lin_300.csv')

for index, rows in df_3.iterrows():
    list_3 = rows
    batch_x_test.append(list_3)
    
df_4 = pd.read_csv('np_t_circ_300.csv')
for index, rows in df_4.iterrows():
    list_4 = rows
    batch_x_test.append(list_4)
    
batch_x_test = np.asarray(batch_x_test)

#data standardization
batch_x_train = batch_x_train.reshape((batch_x_train.shape[0], batch_x_train.shape[1], 1)) 
batch_x_test = batch_x_test.reshape((batch_x_test.shape[0], batch_x_test.shape[1], 1))

num_classes = len(np.unique(batch_y_train))
idx = np.random.permutation(len(batch_x_train))
batch_x_train = batch_x_train[idx]
batch_y_train = batch_y_train[idx]

tf.keras.backend.clear_session()

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=2, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=2, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=2, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=batch_x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 200
batch_size = 20

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=25, min_lr=0.001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_accuracy"],
)
history = model.fit(
    batch_x_train,
    batch_y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.6256 - loss: 0.6445 - val_categorical_accuracy: 0.5200 - val_loss: 1.2104 - learning_rate: 0.0010
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6759 - loss: 0.5776 - val_categorical_accuracy: 0.5200 - val_loss: 0.9526 - learning_rate: 0.0010
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7035 - loss: 0.5702 - val_categorical_accuracy: 0.5200 - val_loss: 0.8690 - learning_rate: 0.0010
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6784 - loss: 0.5558 - val_categorical_accuracy: 0.5300 - val_loss: 0.7500 - learning_rate: 0.0010
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7136 - loss: 0.5395 - val_categorical_accuracy: 0.6600 - val_loss: 0.6480 - learning_rate: 0.0010
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6809 - loss: 0.5503 - val_categorical_accuracy: 0.5300 - val_loss: 0.7560 - learning_rate: 0.0010
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.7136 - loss: 0.5405 - val_categorical_accuracy: 0.6500 - val_loss: 0.5828 - learning_rate: 0.0010
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6809 - loss: 0.5504 - val_categorical_accuracy: 0.6800 - val_loss: 0.6127 - learning_rate: 0.0010
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7035 - loss: 0.5550 - val_categorical_accuracy: 0.7100 - val_loss: 0.5616 - learning_rate: 0.0010
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7085 - loss: 0.5377 - val_categorical_accuracy: 0.7000 - val_loss: 0.5997 - learning_rate: 0.0010
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6985 - loss: 0.5379 - val_categorical_accuracy: 0.7000 - val_loss: 0.5899 - learning_rate: 0.0010
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7312 - loss: 0.5231 - val_categorical_accuracy: 0.7200 - val_loss: 0.5607 - learning_rate: 0.0010
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6985 - loss: 0.5408 - val_categorical_accuracy: 0.6900 - val_loss: 0.5623 - learning_rate: 0.0010
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7186 - loss: 0.5273 - val_categorical_accuracy: 0.7200 - val_loss: 0.5745 - learning_rate: 0.0010
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7236 - loss: 0.5226 - val_categorical_accuracy: 0.7100 - val_loss: 0.5701 - learning_rate: 0.0010
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7211 - loss: 0.5307 - val_categorical_accuracy: 0.6900 - val_loss: 0.5510 - learning_rate: 0.0010
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7186 - loss: 0.5208 - val_categorical_accuracy: 0.6900 - val_loss: 0.5648 - learning_rate: 0.0010
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7387 - loss: 0.5184 - val_categorical_accuracy: 0.6800 - val_loss: 0.5649 - learning_rate: 0.0010
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7462 - loss: 0.5075 - val_categorical_accuracy: 0.6800 - val_loss: 0.5581 - learning_rate: 0.0010
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7261 - loss: 0.5128 - val_categorical_accuracy: 0.7100 - val_loss: 0.5596 - learning_rate: 0.0010
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7362 - loss: 0.5210 - val_categorical_accuracy: 0.6900 - val_loss: 0.5522 - learning_rate: 0.0010
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7161 - loss: 0.5087 - val_categorical_accuracy: 0.6700 - val_loss: 0.5655 - learning_rate: 0.0010
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7362 - loss: 0.5150 - val_categorical_accuracy: 0.6900 - val_loss: 0.5698 - learning_rate: 0.0010
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7387 - loss: 0.5120 - val_categorical_accuracy: 0.6700 - val_loss: 0.5732 - learning_rate: 0.0010
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7261 - loss: 0.5118 - val_categorical_accuracy: 0.6700 - val_loss: 0.5532 - learning_rate: 0.0010
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7337 - loss: 0.5110 - val_categorical_accuracy: 0.6400 - val_loss: 0.5730 - learning_rate: 0.0010
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7312 - loss: 0.5100 - val_categorical_accuracy: 0.6900 - val_loss: 0.5589 - learning_rate: 0.0010
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7261 - loss: 0.5145 - val_categorical_accuracy: 0.7000 - val_loss: 0.5602 - learning_rate: 0.0010
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7337 - loss: 0.5076 - val_categorical_accuracy: 0.6400 - val_loss: 0.5731 - learning_rate: 0.0010
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7513 - loss: 0.5052 - val_categorical_accuracy: 0.6400 - val_loss: 0.5648 - learning_rate: 0.0010
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7186 - loss: 0.5094 - val_categorical_accuracy: 0.7100 - val_loss: 0.5447 - learning_rate: 0.0010
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7236 - loss: 0.5082 - val_categorical_accuracy: 0.6500 - val_loss: 0.5639 - learning_rate: 0.0010
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4872 - val_categorical_accuracy: 0.5700 - val_loss: 0.6214 - learning_rate: 0.0010
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7211 - loss: 0.5119 - val_categorical_accuracy: 0.7100 - val_loss: 0.5430 - learning_rate: 0.0010
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7261 - loss: 0.5023 - val_categorical_accuracy: 0.5400 - val_loss: 0.5918 - learning_rate: 0.0010
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7462 - loss: 0.4986 - val_categorical_accuracy: 0.5700 - val_loss: 0.5909 - learning_rate: 0.0010
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7236 - loss: 0.5183 - val_categorical_accuracy: 0.7200 - val_loss: 0.5596 - learning_rate: 0.0010
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7337 - loss: 0.5011 - val_categorical_accuracy: 0.5700 - val_loss: 0.5915 - learning_rate: 0.0010
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7412 - loss: 0.5012 - val_categorical_accuracy: 0.7100 - val_loss: 0.5567 - learning_rate: 0.0010
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7286 - loss: 0.4936 - val_categorical_accuracy: 0.6800 - val_loss: 0.5615 - learning_rate: 0.0010
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7261 - loss: 0.5078 - val_categorical_accuracy: 0.5500 - val_loss: 0.6304 - learning_rate: 0.0010
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7211 - loss: 0.5005 - val_categorical_accuracy: 0.7200 - val_loss: 0.5409 - learning_rate: 0.0010
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7312 - loss: 0.5034 - val_categorical_accuracy: 0.5800 - val_loss: 0.5972 - learning_rate: 0.0010
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7211 - loss: 0.5180 - val_categorical_accuracy: 0.7000 - val_loss: 0.5439 - learning_rate: 0.0010
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7387 - loss: 0.4993 - val_categorical_accuracy: 0.7000 - val_loss: 0.5722 - learning_rate: 0.0010
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7286 - loss: 0.5096 - val_categorical_accuracy: 0.7000 - val_loss: 0.5507 - learning_rate: 0.0010
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7437 - loss: 0.4965 - val_categorical_accuracy: 0.7100 - val_loss: 0.5534 - learning_rate: 0.0010
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7211 - loss: 0.4990 - val_categorical_accuracy: 0.7100 - val_loss: 0.5718 - learning_rate: 0.0010
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7462 - loss: 0.4985 - val_categorical_accuracy: 0.5900 - val_loss: 0.5938 - learning_rate: 0.0010
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7111 - loss: 0.5088 - val_categorical_accuracy: 0.7000 - val_loss: 0.5494 - learning_rate: 0.0010
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7362 - loss: 0.4924 - val_categorical_accuracy: 0.6400 - val_loss: 0.5683 - learning_rate: 0.0010
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7513 - loss: 0.4837 - val_categorical_accuracy: 0.7100 - val_loss: 0.5488 - learning_rate: 0.0010
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7186 - loss: 0.5032 - val_categorical_accuracy: 0.7100 - val_loss: 0.5500 - learning_rate: 0.0010
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7462 - loss: 0.4863 - val_categorical_accuracy: 0.7200 - val_loss: 0.5427 - learning_rate: 0.0010
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7362 - loss: 0.4892 - val_categorical_accuracy: 0.6900 - val_loss: 0.5441 - learning_rate: 0.0010
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7186 - loss: 0.5152 - val_categorical_accuracy: 0.6900 - val_loss: 0.5441 - learning_rate: 0.0010
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7286 - loss: 0.4973 - val_categorical_accuracy: 0.7200 - val_loss: 0.5395 - learning_rate: 0.0010
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7412 - loss: 0.4925 - val_categorical_accuracy: 0.6600 - val_loss: 0.5591 - learning_rate: 0.0010
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7487 - loss: 0.4947 - val_categorical_accuracy: 0.7200 - val_loss: 0.5398 - learning_rate: 0.0010
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7337 - loss: 0.4924 - val_categorical_accuracy: 0.5600 - val_loss: 0.6332 - learning_rate: 0.0010
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7286 - loss: 0.4913 - val_categorical_accuracy: 0.7200 - val_loss: 0.5421 - learning_rate: 0.0010
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7613 - loss: 0.4842 - val_categorical_accuracy: 0.6100 - val_loss: 0.5818 - learning_rate: 0.0010
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7362 - loss: 0.4922 - val_categorical_accuracy: 0.6800 - val_loss: 0.5597 - learning_rate: 0.0010
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7412 - loss: 0.4964 - val_categorical_accuracy: 0.6500 - val_loss: 0.5551 - learning_rate: 0.0010
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7638 - loss: 0.4751 - val_categorical_accuracy: 0.5500 - val_loss: 0.7032 - learning_rate: 0.0010
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4922 - val_categorical_accuracy: 0.7100 - val_loss: 0.5603 - learning_rate: 0.0010
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7538 - loss: 0.4881 - val_categorical_accuracy: 0.7000 - val_loss: 0.5369 - learning_rate: 0.0010
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7437 - loss: 0.4895 - val_categorical_accuracy: 0.6700 - val_loss: 0.5569 - learning_rate: 0.0010
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7487 - loss: 0.4777 - val_categorical_accuracy: 0.7000 - val_loss: 0.5479 - learning_rate: 0.0010
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7462 - loss: 0.4808 - val_categorical_accuracy: 0.7000 - val_loss: 0.5445 - learning_rate: 0.0010
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7538 - loss: 0.4791 - val_categorical_accuracy: 0.7000 - val_loss: 0.5513 - learning_rate: 0.0010
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7462 - loss: 0.4875 - val_categorical_accuracy: 0.6800 - val_loss: 0.5525 - learning_rate: 0.0010
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7487 - loss: 0.4874 - val_categorical_accuracy: 0.7100 - val_loss: 0.5610 - learning_rate: 0.0010
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7487 - loss: 0.4808 - val_categorical_accuracy: 0.6900 - val_loss: 0.5555 - learning_rate: 0.0010
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.7513 - loss: 0.4825 - val_categorical_accuracy: 0.7100 - val_loss: 0.5368 - learning_rate: 0.0010
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7513 - loss: 0.4853 - val_categorical_accuracy: 0.6700 - val_loss: 0.5637 - learning_rate: 0.0010
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7337 - loss: 0.4801 - val_categorical_accuracy: 0.7100 - val_loss: 0.5468 - learning_rate: 0.0010
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7312 - loss: 0.4785 - val_categorical_accuracy: 0.6500 - val_loss: 0.5632 - learning_rate: 0.0010
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7538 - loss: 0.4765 - val_categorical_accuracy: 0.6700 - val_loss: 0.5620 - learning_rate: 0.0010
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7437 - loss: 0.4780 - val_categorical_accuracy: 0.6700 - val_loss: 0.5546 - learning_rate: 0.0010
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4716 - val_categorical_accuracy: 0.7200 - val_loss: 0.5497 - learning_rate: 0.0010
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7412 - loss: 0.4724 - val_categorical_accuracy: 0.6900 - val_loss: 0.5446 - learning_rate: 0.0010
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7487 - loss: 0.4760 - val_categorical_accuracy: 0.6700 - val_loss: 0.5597 - learning_rate: 0.0010
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7688 - loss: 0.4714 - val_categorical_accuracy: 0.6900 - val_loss: 0.5784 - learning_rate: 0.0010
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7588 - loss: 0.4648 - val_categorical_accuracy: 0.6100 - val_loss: 0.5676 - learning_rate: 0.0010
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7864 - loss: 0.4608 - val_categorical_accuracy: 0.7000 - val_loss: 0.5436 - learning_rate: 0.0010
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7588 - loss: 0.4765 - val_categorical_accuracy: 0.7000 - val_loss: 0.5493 - learning_rate: 0.0010
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4655 - val_categorical_accuracy: 0.7000 - val_loss: 0.5378 - learning_rate: 0.0010
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7462 - loss: 0.4717 - val_categorical_accuracy: 0.5500 - val_loss: 0.6512 - learning_rate: 0.0010
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7462 - loss: 0.4842 - val_categorical_accuracy: 0.6900 - val_loss: 0.5549 - learning_rate: 0.0010
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7337 - loss: 0.4775 - val_categorical_accuracy: 0.6900 - val_loss: 0.5700 - learning_rate: 0.0010
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7111 - loss: 0.4870 - val_categorical_accuracy: 0.6900 - val_loss: 0.5530 - learning_rate: 0.0010
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7538 - loss: 0.4714 - val_categorical_accuracy: 0.6500 - val_loss: 0.5511 - learning_rate: 0.0010
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7487 - loss: 0.4694 - val_categorical_accuracy: 0.6500 - val_loss: 0.5523 - learning_rate: 0.0010
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7312 - loss: 0.4780 - val_categorical_accuracy: 0.6800 - val_loss: 0.5957 - learning_rate: 0.0010
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7487 - loss: 0.4770 - val_categorical_accuracy: 0.6300 - val_loss: 0.6012 - learning_rate: 0.0010
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4713 - val_categorical_accuracy: 0.6500 - val_loss: 0.5450 - learning_rate: 0.0010
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4644 - val_categorical_accuracy: 0.7100 - val_loss: 0.5735 - learning_rate: 0.0010
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7487 - loss: 0.4653 - val_categorical_accuracy: 0.7000 - val_loss: 0.5462 - learning_rate: 0.0010
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7613 - loss: 0.4606 - val_categorical_accuracy: 0.7000 - val_loss: 0.5628 - learning_rate: 0.0010
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4542 - val_categorical_accuracy: 0.6800 - val_loss: 0.5525 - learning_rate: 0.0010
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7387 - loss: 0.4609 - val_categorical_accuracy: 0.7100 - val_loss: 0.5578 - learning_rate: 0.0010
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7638 - loss: 0.4662 - val_categorical_accuracy: 0.6800 - val_loss: 0.6183 - learning_rate: 0.0010
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7688 - loss: 0.4541 - val_categorical_accuracy: 0.7100 - val_loss: 0.5416 - learning_rate: 0.0010
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7588 - loss: 0.4539 - val_categorical_accuracy: 0.6600 - val_loss: 0.5439 - learning_rate: 0.0010
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7538 - loss: 0.4531 - val_categorical_accuracy: 0.7200 - val_loss: 0.5705 - learning_rate: 0.0010
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7714 - loss: 0.4603 - val_categorical_accuracy: 0.6400 - val_loss: 0.6022 - learning_rate: 0.0010
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7387 - loss: 0.4718 - val_categorical_accuracy: 0.6700 - val_loss: 0.5462 - learning_rate: 0.0010
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7613 - loss: 0.4603 - val_categorical_accuracy: 0.6600 - val_loss: 0.5574 - learning_rate: 0.0010
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4588 - val_categorical_accuracy: 0.5400 - val_loss: 0.6828 - learning_rate: 0.0010
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7613 - loss: 0.4598 - val_categorical_accuracy: 0.6100 - val_loss: 0.5847 - learning_rate: 0.0010
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7814 - loss: 0.4631 - val_categorical_accuracy: 0.6600 - val_loss: 0.5777 - learning_rate: 0.0010
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4538 - val_categorical_accuracy: 0.6900 - val_loss: 0.5737 - learning_rate: 0.0010
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7538 - loss: 0.4613 - val_categorical_accuracy: 0.6700 - val_loss: 0.5569 - learning_rate: 0.0010
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7739 - loss: 0.4625 - val_categorical_accuracy: 0.7000 - val_loss: 0.5550 - learning_rate: 0.0010
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4546 - val_categorical_accuracy: 0.6500 - val_loss: 0.5585 - learning_rate: 0.0010
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4515 - val_categorical_accuracy: 0.6200 - val_loss: 0.5920 - learning_rate: 0.0010
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7638 - loss: 0.4509 - val_categorical_accuracy: 0.7100 - val_loss: 0.5834 - learning_rate: 0.0010
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7663 - loss: 0.4579 - val_categorical_accuracy: 0.6700 - val_loss: 0.5544 - learning_rate: 0.0010
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4429 - val_categorical_accuracy: 0.7000 - val_loss: 0.5665 - learning_rate: 0.0010
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7940 - loss: 0.4453 - val_categorical_accuracy: 0.6900 - val_loss: 0.5717 - learning_rate: 0.0010
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7889 - loss: 0.4467 - val_categorical_accuracy: 0.7000 - val_loss: 0.5507 - learning_rate: 0.0010
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7563 - loss: 0.4570 - val_categorical_accuracy: 0.6900 - val_loss: 0.6097 - learning_rate: 0.0010
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7437 - loss: 0.4702 - val_categorical_accuracy: 0.4700 - val_loss: 0.7890 - learning_rate: 0.0010
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7789 - loss: 0.4394 - val_categorical_accuracy: 0.6800 - val_loss: 0.5503 - learning_rate: 0.0010
# Epoch 125: early stopping

# %%
model = keras.models.load_model("best_model.keras")

test_loss, test_acc = model.evaluate(batch_x_test, batch_y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.7149 - loss: 0.5289
# Test accuracy 0.7148594260215759
# Test loss 0.5289459824562073

# %%
metric = "categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
